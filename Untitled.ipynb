# %%
from pyAudioAnalysis import audioBasicIO, ShortTermFeatures 
import matplotlib.pyplot as plt
# Out:
# C:\Users\bebr1\anaconda3\envs\p38\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
[Fs, x] = audioBasicIO.read_audio_file(r"Steel Assault\Qwesta - BLUEPRINT- Steel Assault ver. QWESTA - 01 Opening.wav")
l,r = x[:, 0], x[:, 1] # TODO check if these are correct sides

# %%
import numpy as np
from audioProcessing import spectrogramStats,composerEQProfile

# %%
spectrogramStats("Qwesta - BLUEPRINT- Steel Assault ver. QWESTA - 01 Opening.wav","stats",path="Steel Assault\\")
# Out:
# (1913, 1102)
# {'Filename': 'Qwesta - BLUEPRINT- Steel Assault ver. QWESTA - 01 Opening.wav',
#  'SHA256 hash': '0b14bf5d0bb6829be6d2eaf28a166a770a1741fe860ec70d030815a38f143d09',
#  'Length': 47.872131519274376,
#  'Average spectrograms over time': ([array([8.01473267e-03, 1.13878368e-02, 6.99141991e-02, ...,
#           5.96601658e-05, 6.48077204e-05, 6.93217871e-05]),
#    array([0.01278003, 0.01922997, 0.09751082, ..., 0.00015244, 0.00015882,
#           0.0001808 ]),
#    array([0.00910189, 0.01339114, 0.04444175, ..., 0.00044617, 0.00051075,
#           0.00053487]),
#    array([0.01205055, 0.01610497, 0.03898522, ..., 0.00029149, 0.00034572,
#           0.00049337]),
#    array([0.01693227, 0.02129197, 0.04803984, ..., 0.00030926, 0.00033735,
#           0.00029314]),
#    array([0.02312221, 0.03062686, 0.07088384, ..., 0.00043877, 0.0004771 ,
#           0.00052473]),
#    array([0.02186658, 0.02892724, 0.0696062 , ..., 0.00052209, 0.00049461,
#           0.00060407]),
# ...

# %%
composerEQProfile("Steel Assault","QWESTA")
# Out:
# (1913, 1102)
# (5582, 1102)
# (9273, 1102)
# (5262, 1102)
# (6686, 1102)
# (6077, 1102)
# (8166, 1102)
# (3446, 1102)
# (9520, 1102)
# (11531, 1102)
# (6235, 1102)

# %%
composerEQProfile("Luminous Plume","Aoki")
# Out:
# (4013, 1200)
# (8896, 1200)
# (2453, 1200)
# (9644, 1200)
# (6878, 1200)
# (5500, 1200)
# (8933, 1200)
# (6251, 1200)
# (9570, 1200)
# (5768, 1200)
# (12210, 1200)
# (12607, 1200)
# (3132, 1200)
# (4816, 1200)
# (6094, 1200)
# (1855, 1200)
# (9214, 1200)
# (5536, 1200)
# (8776, 1200)
# (12164, 1200)
# (8082, 1200)
# (5129, 1200)
# (5056, 1200)
# (10850, 1200)
# (2333, 1200)
# (14416, 1200)
# (9134, 1200)
# (10523, 1200)
# (12137, 1200)
# (3683, 1200)
# (2257, 1200)
# (10044, 1200)
# (2415, 1200)
# (3888, 1200)

# %%
F, f_names = ShortTermFeatures.feature_extraction(r, Fs, 0.050*Fs, 0.025*Fs)
plt.subplot(2,1,1); plt.plot(F[0,:]); plt.xlabel('Frame no'); plt.ylabel(f_names[0]) 
plt.subplot(2,1,2); plt.plot(F[1,:]); plt.xlabel('Frame no'); plt.ylabel(f_names[1]); plt.show()

# %%
F, f_names = ShortTermFeatures.feature_extraction(l, Fs, 0.050*Fs, 0.025*Fs)
plt.subplot(2,1,1); plt.plot(F[0,:]); plt.xlabel('Frame no'); plt.ylabel(f_names[0]) 
plt.subplot(2,1,2); plt.plot(F[1,:]); plt.xlabel('Frame no'); plt.ylabel(f_names[1]); plt.show()

# %%
y, t_axis, f_axis = ShortTermFeatures.spectrogram(l, Fs, 0.050*Fs, 0.025*Fs)
# Out:
# (1913, 1102)

# %%
len(t_axis)
# Out:
# 1913

# %%
type(f_axis)
# Out:
# list

# %%
test = np.array([[0,1],[2,3]])

# %%
np.mean(test,axis=0)
# Out:
# array([1., 2.])
